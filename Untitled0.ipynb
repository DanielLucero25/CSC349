# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielLucero25/CSC349/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.Based on the instructional videos, what are the key steps for managing files between Google Colab and GitHub? Based on the instructional video the key steps for managing files between google colab and github are to create your notebook in colab and save your work and then push your notebook to your GitHub repository
#
# 2.Did all Module 0 notebooks execute successfully in Colab on the first try, or did you need to adjust any syntax or dependencies? All module 0 notebooks executed successfully and I did not need to make any adjustments
#
# 3.Explain how you created your repository and organized your files (whether using VS Code or the GitHub web interface). I created and organized my repository on the GitHub web interface and used the instructional videos as a template.
#
# 4.Why is establishing a strong command of basic Python data structures and syntax critical before moving on to core machine learning algorithms? establishing a strong command of basic python data structures and syntax is critical before moving on to core machine learning algorithms because Knowing python basics is essential to working with the data used in machine learning
